# %%
from zamboni import DBConnector, Exporter
from zamboni.pd_helpers import filter_by_game_type, filter_by_season, filter_by_team, won_by_team, _wins_game
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from sklearn.model_selection import LinearRegression

# %%
db_con = DBConnector('../data/zamboni.db')
conn = db_con.connect_db()

# %%
sql = 'SELECT * ' \
    'FROM games_per_team ' \
    'INNER JOIN games ON games_per_team.gameID = games.id ' \
    'INNER JOIN teams ON games_per_team.teamID = teams.id ' \
        
teams_sql = 'SELECT * FROM teams'

# %%
df = pd.read_sql(sql, conn)
teams_info_df = pd.read_sql(teams_sql, conn)

# %%
print(df)
# Out:
#        gameID  teamID  won  tied  goals  oppGoals    id       apiID  seasonID  \
# 0           1      21    1     0      3         2     1  2019011001  20192020
# 1           2      28    0     1      2         4     2  2019011002  20192020
# 2           3      24    0     1      1         4     3  2019011003  20192020
# 3           4       5    0     1      0         5     4  2019011004  20192020
# 4           5      20    0     1      2         3     5  2019011005  20192020
# ...       ...     ...  ...   ...    ...       ...   ...         ...       ...
# 11772    5905      10    0     0      1         2  5905  2024020189  20242025
# 11773    5906       9    1     1      4         2  5906  2024020190  20242025
# 11774    5907      31    1     1      4         2  5907  2024020191  20242025
# 11775    5908      12    1     1      3         0  5908  2024020192  20242025
# 11776    5909      23    1     1      3         0  5909  2024020193  20242025
#
#        homeTeamID  ...  awayTeamGoals gameTypeID  lastPeriodTypeID  outcome  \
# 0              21  ...              2          1                OT        1
# 1              28  ...              4          1               REG        0
# 2              24  ...              4          1               REG        0
# 3               5  ...              5          1               REG        0
# 4              20  ...              3          1               REG        0
# ...           ...  ...            ...        ...               ...      ...
# 11772          20  ...              1          2                OT        1
# 11773          24  ...              4          2               REG        0
# 11774          30  ...              4          2               REG        0
# 11775          11  ...              3          2               REG        0
# 11776           9  ...              3          2               REG        0
#
#        id  apiID                 name  nameAbbrev conferenceAbbrev  \
# 0      21   None  Philadelphia Flyers         PHI                E
# 1      28   None   Montréal Canadiens         MTL                E
# 2      24   None       Calgary Flames         CGY                W
# 3       5   None     Florida Panthers         FLA                E
# 4      20   None       Minnesota Wild         MIN                W
# ...    ..    ...                  ...         ...              ...
# 11772  10   None  Toronto Maple Leafs         TOR                E
# 11773   9   None      Edmonton Oilers         EDM                W
# 11774  31   None   Chicago Blackhawks         CHI                W
# 11775  12   None    Los Angeles Kings         LAK                W
# 11776  23   None    New Jersey Devils         NJD                E
#
#        divisionAbbrev
# 0                   M
# 1                   A
# 2                   P
# 3                   A
# 4                   C
# ...               ...
# 11772               A
# 11773               P
# 11774               C
# 11775               P
# 11776               M
#
# [11777 rows x 26 columns]

# %%
print(teams_info_df)
# Out:
#     id apiID                   name nameAbbrev conferenceAbbrev divisionAbbrev
# 0    1  None       New York Rangers        NYR                E              M
# 1    2  None           Dallas Stars        DAL                W              C
# 2    3  None    Carolina Hurricanes        CAR                E              M
# 3    4  None          Winnipeg Jets        WPG                W              C
# 4    5  None       Florida Panthers        FLA                E              A
# 5    6  None      Vancouver Canucks        VAN                W              P
# 6    7  None          Boston Bruins        BOS                E              A
# 7    8  None     Colorado Avalanche        COL                W              C
# 8    9  None        Edmonton Oilers        EDM                W              P
# 9   10  None    Toronto Maple Leafs        TOR                E              A
# 10  11  None    Nashville Predators        NSH                W              C
# 11  12  None      Los Angeles Kings        LAK                W              P
# 12  13  None    Tampa Bay Lightning        TBL                E              A
# 13  14  None   Vegas Golden Knights        VGK                W              P
# 14  15  None     New York Islanders        NYI                E              M
# 15  16  None        St. Louis Blues        STL                W              C
# 16  17  None    Washington Capitals        WSH                E              M
# 17  18  None      Detroit Red Wings        DET                E              A
# 18  19  None    Pittsburgh Penguins        PIT                E              M
# 19  20  None         Minnesota Wild        MIN                W              C
# 20  21  None    Philadelphia Flyers        PHI                E              M
# 21  22  None         Buffalo Sabres        BUF                E              A
# 22  23  None      New Jersey Devils        NJD                E              M
# 23  24  None         Calgary Flames        CGY                W              P
# 24  25  None         Seattle Kraken        SEA                W              P
# 25  26  None        Ottawa Senators        OTT                E              A
# 26  27  None        Arizona Coyotes        ARI                W              C
# 27  28  None     Montréal Canadiens        MTL                E              A
# 28  29  None  Columbus Blue Jackets        CBJ                E              M
# 29  30  None          Anaheim Ducks        ANA                W              P
# 30  31  None     Chicago Blackhawks        CHI                W              C
# 31  32  None        San Jose Sharks        SJS                W              P

# %%
print(df.iloc[0])
# Out:
# gameID                       1
# teamID                      21
# won                          1
# tied                         0
# id                           1
# apiID               2019011001
# seasonID              20192020
# homeTeamID                  21
# awayTeamID                  19
# datePlayed          2020-07-28
# dayOfYrPlayed              210
# yrPlayed                  2020
# timePlayed            20:00:00
# homeTeamGoals                3
# awayTeamGoals                2
# gameTypeID                   1
# lastPeriodTypeID            OT
# outcome                      1
# Name: 0, dtype: object

# %%
season_id = 20222023

season_df = filter_by_season(df, season_id)
season_grouped_df = season_df.groupby(by='nameAbbrev', as_index=False)
win_df = season_grouped_df.agg({'won':['count','sum'], 'tied':['sum']})
win_df.columns = ['nameAbbrev', 'played','won','tied']
# Out:
#    nameAbbrev  won_count  won_sum  tied_sum
# 0         ANA         89       27        41
# 1         ARI         89       28        29
# 2         BOS         95       71        45
# 3         BUF         88       47        49
# 4         CAR        101       63        43
# 5         CBJ         89       29        34
# 6         CGY         90       42        41
# 7         CHI         88       27        43
# 8         COL         95       57        55
# 9         DAL        107       58        54
# 10        DET         90       38        43
# 11        EDM        102       61        52
# 12        FLA        108       57        50
# 13        LAK         95       52        42
# 14        MIN         94       53        42
# 15        MTL         89       31        42
# 16        NJD        100       61        53
# 17        NSH         86       45        41
# 18        NYI         94       48        37
# 19        NYR         94       52        48
# 20        OTT         90       44        36
# 21        PHI         88       32        38
# 22        PIT         88       43        37
# 23        SEA        101       56        54
# 24        SJS         88       27        50
# 25        STL         89       42        46
# 26        TBL         92       49        36
# 27        TOR        100       60        49
# 28        VAN         88       40        42
# 29        VGK        111       71        55
# 30        WPG         92       50        40
# 31        WSH         88       39        43

# %%
records = win_df[['nameAbbrev', 'won_sum']].sort_values(by='won_sum', ascending=True)

abbrevs = records['nameAbbrev']
wins = records['won_sum']
ys = [2*i for i in range(len(records))]

fig, ax = plt.subplots(figsize=(10,10))
plt.barh(ys, wins)
plt.yticks(ys, abbrevs)
plt.title('Wins (2022-2023)', size=20)
plt.ylabel('Team')
plt.xlabel('Wins')
plt.show()

# %%
a_df = filter_by_team(df, 1)
a_df = filter_by_game_type(a_df, 2)
a_df = filter_by_season(a_df, 20222023)
#a_df = won_by_team(a_df, 1)
print(len(a_df))
print(a_df)

# %%
fil_df = a_df
fil_df['Won'] = df.apply(_wins_game, axis=1)
fil_df['Lost'] = ~fil_df['Won']
fil_df['WonLast'] = fil_df['Won'].shift(1)
fil_df['WonNext'] = fil_df['Won'].shift(-1)
fil_df['WonAndNext'] = fil_df['Won'] & fil_df['WonNext']
fil_df['LostWonNext'] = fil_df['Lost'] & fil_df['WonNext']

# %%
print(fil_df.iloc[0])
# Out:
# id                                 6169
# apiID                        2022020003
# seasonID                       20222023
# homeTeamID                            1
# awayTeamID                           13
# datePlayed                   2022-10-11
# timePlayed                     23:30:00
# homeTeamGoals                         3
# awayTeamGoals                         1
# gameTypeID                            2
# lastPeriodTypeID                    REG
# outcome                               1
# id                                    1
# apiID                              None
# name                   New York Rangers
# nameAbbrev                          NYR
# conferenceAbbrev                      E
# divisionAbbrev                        M
# id                                   13
# apiID                              None
# name                Tampa Bay Lightning
# nameAbbrev                          TBL
# conferenceAbbrev                      E
# divisionAbbrev                        A
# Won                                True
# Lost                              False
# WonLast                             NaN
# WonNext                            True
# WonAndNext                         True
# LostWonNext                       False
# Name: 6163, dtype: object

# %%
print(f'Games: {len(fil_df)}')
print(f'Wins: {sum(fil_df["Won"])}')
print(sum(fil_df['Won'])/len(fil_df))
# Out:
# Games: 82
# Wins: 47
# 0.573170731707317

# %%
print(sum(fil_df[:-1]['WonAndNext']) / sum(fil_df[:-1]['Won']))
print(sum(fil_df[:-1]['LostWonNext']) / sum(fil_df[:-1]['Lost']))
# Out:
# 0.574468085106383
# 0.5588235294117647

# %% [markdown]
# ## Games with all previous games (2022-2023)

# %% [markdown]
# #### Each row is a game and previous game for the same team and season. This is intended to allow for calculation of wins/record to date in that season for a game

# %%
sql = 'SELECT games_per_team.gameID as gameID, ' \
        'games_per_team.won as won, ' \
        'games_per_team.teamID as teamID, ' \
        'games.datePlayed as datePlayed, ' \
        'games.seasonID as seasonID, ' \
        'other_games.datePlayed as prevDatePlayed, ' \
        'other_games_per_team.won as prevWon ' \
    'FROM games_per_team ' \
    'INNER JOIN games ON games_per_team.gameID = games.id ' \
    'INNER JOIN teams ON games_per_team.teamID = teams.id ' \
    'INNER JOIN games other_games ON games_per_team.teamID = other_games.homeTeamID ' \
        'OR games_per_team.teamID = other_games.awayTeamID ' \
    'INNER JOIN games_per_team other_games_per_team ON other_games.id = other_games_per_team.gameID ' \
        'AND games_per_team.teamID = other_games_per_team.teamID ' \
    'WHERE games.datePlayed > other_games.datePlayed ' \
        'AND games.seasonID = other_games.seasonID ' \
        'AND games.seasonID = 20222023 ' \
        
df = pd.read_sql(sql, conn)

# %%
print(df)
# Out:
#         gameID  won  teamID  datePlayed  seasonID prevDatePlayed  prevWon
# 0         2619    1      11  2022-09-27  20222023     2022-09-26        0
# 1         2623    0      19  2022-09-27  20222023     2022-09-25        1
# 2         2628    1       2  2022-09-28  20222023     2022-09-27        0
# 3         2631    0       8  2022-09-28  20222023     2022-09-26        1
# 4         2632    1      25  2022-09-28  20222023     2022-09-27        1
# ...        ...  ...     ...         ...       ...            ...      ...
# 139588    4104    0       5  2023-06-14  20222023     2023-03-21        0
# 139589    4104    0       5  2023-06-14  20222023     2023-03-27        0
# 139590    4104    0       5  2023-06-14  20222023     2023-04-17        0
# 139591    4104    0       5  2023-06-14  20222023     2023-06-04        0
# 139592    4104    0       5  2023-06-14  20222023     2023-06-06        0
#
# [139593 rows x 7 columns]

# %%
#team_df = df[df['teamID'] == 1]
#print(team_df)
# Out:
#         gameID  won  teamID  datePlayed  seasonID prevDatePlayed  prevWon
# 57        2676    0       1  2022-10-05  20222023     2022-09-26        1
# 114       2704    1       1  2022-10-11  20222023     2022-10-05        0
# 115       2704    1       1  2022-10-11  20222023     2022-09-26        1
# 244       2740    1       1  2022-10-17  20222023     2022-10-05        0
# 245       2740    1       1  2022-10-17  20222023     2022-09-26        1
# ...        ...  ...     ...         ...       ...            ...      ...
# 137717    4066    0       1  2023-05-02  20222023     2023-03-12        0
# 137718    4066    0       1  2023-05-02  20222023     2023-03-30        0
# 137719    4066    0       1  2023-05-02  20222023     2023-03-31        0
# 137720    4066    0       1  2023-05-02  20222023     2023-04-07        0
# 137721    4066    0       1  2023-05-02  20222023     2023-04-27        0
#
# [4369 rows x 7 columns]

# %%
print(df[df['gameID'] == 2643][['teamID', 'gameID', 'won', 'datePlayed', 'prevDatePlayed', 'prevWon']])
# Out:
#         teamID  gameID  won  datePlayed prevDatePlayed  prevWon
# 14          23    2643    0  2022-09-30     2022-09-27        1
# 34527       23    2643    0  2022-09-30     2022-09-26        1
# 69814        1    2643    1  2022-09-30     2022-09-26        1
# 105042       1    2643    1  2022-09-30     2022-09-27        0

# %% [markdown]
# ## Games with win/goals summaries to date

# %%
sql = 'SELECT gameID, '\
        'teamID, '\
		'seasonID, '\
		'won, '\
		'CAST(SUM(prevWon) AS REAL) / COUNT(*) AS prevWonPercentage, '\
        'CAST(SUM(prevGoals) AS REAL) / COUNT(*) AS prevGoalsScoredPerGame, '\
        'CAST(SUM(prevOppGoals) AS REAL) / COUNT(*) AS prevGoalsAgainstPerGame, '\
		'SUM(prevWon), '\
		'SUM(prevGoals), '\
		'SUM(prevOppGoals), '\
		'COUNT(*) '\
	'FROM games_with_previous '\
	'GROUP BY gameID, seasonID'

# %%
df = pd.read_sql(sql, conn)

# %%
print(df)
# Out:
#       gameID  teamID  seasonID  won  prevWonPercentage  \
# 0         13       3  20192020    1           0.000000
# 1         14       9  20192020    0           1.000000
# 2         15      15  20192020    1           0.500000
# 3         16      19  20192020    0           0.000000
# 4         17      24  20192020    1           0.500000
# ...      ...     ...       ...  ...                ...
# 5806    5905      20  20242025    1           0.636364
# 5807    5906      24  20242025    0           0.500000
# 5808    5907      30  20242025    0           0.375000
# 5809    5908      11  20242025    0           0.470588
# 5810    5909       9  20242025    0           0.425000
#
#       prevGoalsScoredPerGame  prevGoalsAgainstPerGame  SUM(prevWon)  \
# 0                   1.500000                 2.500000             0
# 1                   4.000000                 0.500000             2
# 2                   1.000000                 3.000000             1
# 3                   2.000000                 3.500000             0
# 4                   2.500000                 2.500000             1
# ...                      ...                      ...           ...
# 5806                3.666667                 2.818182            21
# 5807                2.972222                 3.416667            18
# 5808                2.531250                 3.093750            12
# 5809                3.088235                 3.176471            16
# 5810                2.900000                 3.500000            17
#
#       SUM(prevGoals)  SUM(prevOppGoals)  COUNT(*)
# 0                  3                  5         2
# 1                  8                  1         2
# 2                  2                  6         2
# 3                  4                  7         2
# 4                  5                  5         2
# ...              ...                ...       ...
# 5806             121                 93        33
# 5807             107                123        36
# 5808              81                 99        32
# 5809             105                108        34
# 5810             116                140        40
#
# [5811 rows x 11 columns]

# %% [markdown]
# ## Win percentage to date

# %%
b, a = np.polyfit(df['prevWonPercentage'], df['won'], deg=1)
x_vals = np.linspace(0,1,100)
plt.plot(x_vals, a + b*x_vals, color='k')
plt.scatter(df['prevWonPercentage'], df['won'])
plt.title('Win vs. Previous Win Percentage')
plt.xlabel('Previous Win Percentage')
plt.ylabel('Win Y/N')
plt.show()

# %%
win_mask = df['won'] == 1
lost_mask = np.logical_not(win_mask)
won_percentages = df['prevWonPercentage'][win_mask]
print('Mean previous win percentage when game is won:')
print(f'{round(np.mean(won_percentages)*100, 1)}%')
# Out:
# Mean previous win percentage when game is won:
# 51.0%

# %%
lost_percentages = df['prevWonPercentage'][lost_mask]
print('Mean previous win percentage when game is lost:')
print(f'{round(np.mean(lost_percentages)*100, 1)}%')
# Out:
# Mean previous win percentage when game is lost:
# 50.8%

# %%
bins = [np.array([0,0.05]) + 0.05*n for n in range(20)]
win_percentages = df['prevWonPercentage']
outcomes = df['won']
plot_x = []
plot_y = []
for low_val, high_val in bins:
    above_mask = win_percentages > low_val
    below_mask = win_percentages < high_val
    mask = np.all([above_mask,below_mask], axis=0)
    binned_outcomes = outcomes[mask]
    if len(binned_outcomes) > 0:
        plot_y += [sum(binned_outcomes)/len(binned_outcomes)]
    else:
        plot_y += [0]
    plot_x += [(low_val + high_val)/2]

# %%
b, a = np.polyfit(plot_x[4:16], plot_y[4:16], deg=1)
x_vals = np.linspace(0,1,100)
plt.scatter(plot_x, plot_y)
plt.plot(x_vals, a + b*x_vals)
plt.title('Average win percentage vs. binned previous win percentage')
plt.show()

# %% [markdown]
# ## Average goals scored per game

# %%
b, a = np.polyfit(df['prevGoalsScoredPerGame'], df['won'], deg=1)
x_vals = np.linspace(0,10,100)
plt.plot(x_vals, a + b*x_vals, color='k')
plt.scatter(df['prevGoalsScoredPerGame'], df['won'])
plt.title('Win vs. Previous Goals Scored Per Game')
plt.xlabel('Goals Per Game')
plt.ylabel('Win Y/N')
plt.show()

# %%
b, a = np.polyfit(df['prevGoalsAgainstPerGame'], df['won'], deg=1)
x_vals = np.linspace(0,6,100)
plt.plot(x_vals, a + b*x_vals, color='k')
plt.scatter(df['prevGoalsAgainstPerGame'], df['won'])
plt.title('Win vs. Previous Goals Scored Per Game')
plt.xlabel('Goals Per Game')
plt.ylabel('Win Y/N')
plt.show()

# %% [markdown]
# ## Won previous encounter between teams

# %%
sql = 'SELECT gameID, '\
	'teamID, '\
	'oppTeamID, '\
	'won, '\
	'prevWon '\
	'FROM ( SELECT gameID AS prevSameOppGameID, '\
		'teamID AS prevSameOppTeamID, '\
		'MAX(prevDatePlayed) AS prevSameOppDatePlayed '\
	'FROM games_with_previous '\
	'WHERE oppTeamID=prevOppTeamID '\
	'GROUP BY gameID ) same_opp '\
	'INNER JOIN games_with_previous '\
		'ON same_opp.prevSameOppGameID=games_with_previous.gameID '\
	'WHERE seasonID=20202021 '\
	'ORDER BY gameID'

# %%
df = pd.read_sql(sql, conn)

# %%
print(df)
# Out:
#        gameID  teamID  oppTeamID  won  prevWon
# 0         154       9          6    1        0
# 1         154       6          9    0        1
# 2         158      22         17    0        0
# 3         158      17         22    1        1
# 4         159      21         19    1        1
# ...       ...     ...        ...  ...      ...
# 56314    1094      28         13    0        0
# 56315    1094      28         13    0        0
# 56316    1094      28         13    0        0
# 56317    1094      28         13    0        0
# 56318    1094      28         13    0        0
#
# [56319 rows x 5 columns]

# %%
won = df['won']
prev_won = df['prevWon']
prev_won_mask = prev_won==1
prev_lost_mask = prev_won==0
won_prev_won = [int(val) for val in won[prev_won_mask]]
won_prev_lost = [int(val) for val in won[prev_lost_mask]]
print(f'Percentage of games won when won previous encounter: {sum(won[prev_won_mask]) / len(won[prev_won_mask])*100:.1f}%')
print(f'Percentage of games won when lost previous encounter: {sum(won[prev_lost_mask]) / len(won[prev_lost_mask])*100:.1f}%')
print()
plt.hist(won_prev_won, density=True, alpha=0.5, label='Won previous')
plt.hist(won_prev_lost, density=True, alpha=0.5, label='Lost previous')
plt.legend()
plt.title('Outcome by previous outcome')
plt.xlabel('Win/loss')
plt.show()
# Out:
# Percentage of games won when won previous encounter: 51.9%
# Percentage of games won when lost previous encounter: 47.9%
